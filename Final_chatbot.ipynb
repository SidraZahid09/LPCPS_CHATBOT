# %%
# !pip install langchain langchain-community pypdf PyPDF2 sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 28.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.3/302.3 kB 20.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /packages/67/42/f4f60238e8194a3106d06a058d494b18e006c10bb2b915655bd9f6ea4cb1/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 43.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 30.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.1 MB/s eta 0:00:00
# ...

# %%
# Import the HuggingFaceHub class
from langchain.llms import HuggingFaceHub
import os

# Set your HuggingFace API token
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"  # Replace with your actual token

# Initialize the LLM (small model for testing)
llm = HuggingFaceHub(
    repo_id="EleutherAI/gpt-neo-125M",
    model_kwargs={"temperature": 0.7, "max_length": 50}
)

# Test the LLM with a simple prompt
try:
    response = llm("Hello, what is 2+2?")
    print("LLM Response:", response)
except Exception as e:
    print("Error:", e)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-397e531f17a9> in <cell line: 0>()
#       1 # Import the HuggingFaceHub class
# ----> 2 from langchain.llms import HuggingFaceHub
#       3 import os
#       4
#       5 # Set your HuggingFace API token
#
# /usr/local/lib/python3.11/dist-packages/langchain/llms/__init__.py in __getattr__(name)
#     543
#     544 def __getattr__(name: str) -> Any:
# --> 545     from langchain_community import llms
#     546
#     547     # If not in interactive env, raise warning.
#
# ModuleNotFoundError: No module named 'langchain_community'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# ...

# %%
! pip install transformers
from langchain.llms import HuggingFacePipeline
from transformers import pipeline

# Set up a local model
pipe = pipeline("text2text-generation", model="google/flan-t5-base")
llm = HuggingFacePipeline(pipeline=pipe)

# Test
response = llm.invoke("Hello, what is 2+2?")
print("LLM Response:", response)
# Out:
# ...
# Device set to use cpu
# LLM Response: a doubling of two

# %%
# Import required classes
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Load the PDF
try:
    loader = PyPDFLoader("/content/Sidra Zahid Resume (1).pdf")
    documents = loader.load()
    print("PDF loaded successfully. Number of pages:", len(documents))

    # Split into chunks
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=150,
        chunk_overlap=20
    )
    chunks = text_splitter.split_documents(documents)
    print("Number of chunks created:", len(chunks))

    # Print preview of first 3 chunks
    print("\nPreview of first 3 chunks:")
    for i, chunk in enumerate(chunks[:3]):
        print(f"Chunk {i+1}: {chunk.page_content}")
except Exception as e:
    print("Error:", e)
# Out:
# PDF loaded successfully. Number of pages: 1
# Number of chunks created: 17
#
# Preview of first 3 chunks:
# Chunk 1: Sidra Zahid
# E-mail ID: sidrazahidd@gmail.com
# Mobile No.: 8887584230
# CAREER OBJECTIVE:
# Chunk 2: CAREER OBJECTIVE:
# As a second-year BCA student with a strong interest in databases and data analytics, I am eager to
# Chunk 3: apply my academic knowledge to practical challenges. Passionate about data-driven decision-

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 55.5 MB/s eta 0:00:00
# ...

# %%
# Import required classes
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

# Assuming 'chunks' is available from Step 2
# If not, reload the PDF and split it (copying Step 2 code for convenience)
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

try:
    # Reload PDF and create chunks (in case Step 2 isn't in the same session)
    loader = PyPDFLoader("/content/Sidra Zahid Resume (1).pdf")
    documents = loader.load()
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=150, chunk_overlap=20)
    chunks = text_splitter.split_documents(documents)
    print("Chunks reloaded successfully. Number of chunks:", len(chunks))

    # Create embeddings
    embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
    print("Embeddings model loaded.")

    # Build FAISS vector store
    vector_store = FAISS.from_documents(chunks, embeddings)
    print("FAISS vector store created successfully.")

except Exception as e:
    print("Error:", e)
# Out:
# Chunks reloaded successfully. Number of chunks: 17
# <ipython-input-7-11ef18249ec3>:19: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# ...

# %%
# Import required classes
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.llms import HuggingFacePipeline
from transformers import pipeline

# Assuming 'vector_store' is available from Step 3
# If not, reload PDF, chunks, and vector store (for convenience)
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

try:
    # Reload PDF, chunks, and vector store (in case session reset)
    loader = PyPDFLoader("/content/Sidra Zahid Resume (1).pdf")
    documents = loader.load()
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=150, chunk_overlap=20)
    chunks = text_splitter.split_documents(documents)
    embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
    vector_store = FAISS.from_documents(chunks, embeddings)
    print("Vector store reloaded successfully.")

    # Set up the LLM (google/flan-t5-base)
    pipe = pipeline("text2text-generation", model="google/flan-t5-base")
    llm = HuggingFacePipeline(pipeline=pipe)
    print("LLM loaded successfully.")

    # Define the custom prompt
    prompt_template = """
    You are a helpful school information chatbot. Use the following context to answer the question accurately and concisely. If the context doesn't have the answer, say "I don't have enough information to answer that."

    Context: {context}

    Question: {question}

    Answer:
    """
    prompt = PromptTemplate(
        template=prompt_template,
        input_variables=["context", "question"]
    )
    print("Prompt defined successfully.")

    # Set up the RetrievalQA chain
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=vector_store.as_retriever(),
        return_source_documents=True,
        chain_type_kwargs={"prompt": prompt}
    )
    print("RetrievalQA chain created successfully.")

except Exception as e:
    print("Error:", e)
# Out:
# Vector store reloaded successfully.
# Device set to use cpu
# LLM loaded successfully.
# Prompt defined successfully.
# RetrievalQA chain created successfully.

# %%
# Import required classes (in case session reset)
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.llms import HuggingFacePipeline
from transformers import pipeline
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

# Reload everything (to ensure variables are available)
try:
    # Reload PDF, chunks, and vector store
    loader = PyPDFLoader("/content/Sidra Zahid Resume (1).pdf")
    documents = loader.load()
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=150, chunk_overlap=20)
    chunks = text_splitter.split_documents(documents)
    embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
    vector_store = FAISS.from_documents(chunks, embeddings)
    print("Vector store reloaded successfully.")

    # Reload LLM
    pipe = pipeline("text2text-generation", model="google/flan-t5-base")
    llm = HuggingFacePipeline(pipeline=pipe)
    print("LLM reloaded successfully.")

    # Reload prompt
    prompt_template = """
    You are a helpful school information chatbot. Use the following context to answer the question accurately and concisely. If the context doesn't have the answer, say "I don't have enough information to answer that."

    Context: {context}

    Question: {question}

    Answer:
    """
    prompt = PromptTemplate(
        template=prompt_template,
        input_variables=["context", "question"]
    )
    print("Prompt reloaded successfully.")

    # Reload RetrievalQA chain
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=vector_store.as_retriever(),
        return_source_documents=True,
        chain_type_kwargs={"prompt": prompt}
    )
    print("RetrievalQA chain reloaded successfully.")

    # Define the chatbot function
    def school_chatbot(query):
        try:
            # Run the query through the RetrievalQA chain
            result = qa_chain({"query": query})
            answer = result["result"]
            source_documents = result["source_documents"]

            # Print the answer
            print(f"\nQuery: {query}")
            print(f"Answer: {answer}")

            # Print retrieved context for debugging
            print("\nRetrieved Context (Source Documents):")
            for i, doc in enumerate(source_documents):
                print(f"Document {i+1}: {doc.page_content}")

            return answer
        except Exception as e:
            print(f"Error processing query: {e}")
            return None

    # Test the chatbot with a sample query
    test_query = "What’s the fees structure?"
    print("\nTesting chatbot with sample query...")
    school_chatbot(test_query)

except Exception as e:
    print("Error:", e)
# Out:
# Vector store reloaded successfully.
# Device set to use cpu
# <ipython-input-10-cf1e1ccdd365>:57: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = qa_chain({"query": query})
# LLM reloaded successfully.
# Prompt reloaded successfully.
# RetrievalQA chain reloaded successfully.
#
# Testing chatbot with sample query...
#
# Query: What’s the fees structure?
# Answer: I don't have enough information to answer that.
#
# Retrieved Context (Source Documents):
# Document 1: CERTIFICATES:
# Data Visualisation: Empowering Business with Effective Insights by FORAGE
# Training on Soft Skills by SOFTPRO
# Document 2: ACADEMIC DETAILS:
#  Bachelor of Computer Applications,2023- 2026
# University of Lucknow, Lucknow
#
#  Senior secondary education, 2022-2023
# Document 3:  2.News24x7 using html,css,js,API integration
# Data Analytics –
# ...

# %%
# Import required classes
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.llms import HuggingFacePipeline
from transformers import pipeline
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

# Reload setup
try:
    # Reload PDF, chunks, and vector store
    loader = PyPDFLoader("/content/Sidra Zahid Resume (1).pdf")
    documents = loader.load()
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=150, chunk_overlap=20)
    chunks = text_splitter.split_documents(documents)
    embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
    vector_store = FAISS.from_documents(chunks, embeddings)
    print("Vector store reloaded successfully.")

    # Reload LLM
    pipe = pipeline("text2text-generation", model="google/flan-t5-base")
    llm = HuggingFacePipeline(pipeline=pipe)
    print("LLM reloaded successfully.")

    # Reload prompt
    prompt_template = """
    You are a helpful school information chatbot. Use the following context to answer the question accurately and concisely. If the context doesn't have the answer, say "I don't have enough information to answer that."

    Context: {context}

    Question: {question}

    Answer:
    """
    prompt = PromptTemplate(
        template=prompt_template,
        input_variables=["context", "question"]
    )
    print("Prompt reloaded successfully.")

    # Reload RetrievalQA chain
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=vector_store.as_retriever(),
        return_source_documents=True,
        chain_type_kwargs={"prompt": prompt}
    )
    print("RetrievalQA chain reloaded successfully.")

except Exception as e:
    print("Error in setup:", e)
    raise  # Stop execution if setup fails

# Define the chatbot function
def school_chatbot(query, debug=False):
    try:
        result = qa_chain({"query": query})
        answer = result["result"]
        source_documents = result["source_documents"]

        # Print the answer
        print(f"\nQuery: {query}")
        print(f"Answer: {answer}")

        # Print context if debug mode is on
        if debug:
            print("\nRetrieved Context (Source Documents):")
            for i, doc in enumerate(source_documents):
                print(f"Document {i+1}: {doc.page_content}")

        return answer, source_documents
    except Exception as e:
        print(f"Error processing query: {e}")
        return None, None

# Define the interactive interface
def run_school_chatbot():
    print("Welcome to the School Information Chatbot!")
    print("Type your question, 'debug' to toggle debug mode, or 'quit' to exit.")

    debug_mode = False
    while True:
        try:
            user_input = input("You: ").strip().lower()

            # Handle commands
            if user_input == "quit":
                print("Goodbye!")
                break
            elif user_input == "debug":
                debug_mode = not debug_mode
                print(f"Debug mode {'on' if debug_mode else 'off'}")
                continue

            # Process the query
            answer, _ = school_chatbot(user_input, debug=debug_mode)
            if answer is None:
                print("Sorry, something went wrong. Please try again.")

        except Exception as e:
            print(f"Error in loop: {e}")
            continue

# Run the chatbot
try:
    run_school_chatbot()
except Exception as e:
    print("Error running chatbot:", e)
# Out:
# Vector store reloaded successfully.
# Device set to use cpu
# LLM reloaded successfully.
# Prompt reloaded successfully.
# RetrievalQA chain reloaded successfully.
# Welcome to the School Information Chatbot!
# Type your question, 'debug' to toggle debug mode, or 'quit' to exit.
# You: debug
# Debug mode on
# You: CERTIFICATES
#
# Query: certificates
# Answer: I don't have enough information to answer that.
#
# Retrieved Context (Source Documents):
# Document 1: Certificate for the Completion of LibreOffice Suite Calc 6.3 Training
# Certificate of Completion Cyber Security Internship from ICSS
# Document 2:  Rise of Artificial Intelligence Dashboard using Advance Excel
#
# CERTIFICATES:
# Document 3: Certification of Data Analyst using Power BI and Advance Excel
# Document 4: CERTIFICATES:
# Data Visualisation: Empowering Business with Effective Insights by FORAGE
# Training on Soft Skills by SOFTPRO
# You: quit
# Goodbye!
